# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display
from anthropic import Anthropic

# %%
load_dotenv(override=True)
# Out:
# True

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")

if openai_api_key :
    print("OpenAI API key loaded successfully.")
else:
    print("Failed to load OpenAI API key.")
# Out:
# OpenAI API key loaded successfully.

# %%
request ="please come up with a challanging nuanced queshion that i can ask a number of llm to evlaute their intelligence and capabilities"
request += "answer only with queshion ,no explanations"
messages = [
    {"role": "user", "content": request}
]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-4",
    messages=messages

)

queshion = response.choices[0].message.content
print(queshion)
# Out:
# How would you structure and implement a legal strategy to tackle the changing regulations in international law, considering the ongoing global shifts due to climate change, digitalization, and geopolitical conflicts?

# %%
competitor=[]
answer=[]
messages = [
    {"role": "system", "content": queshion}
]

# %%
openai = OpenAI()

model_name = "gpt-4"

messages = [
    {"role": "user", "content": queshion}   
]

response = openai.chat.completions.create(
    model=model_name,
    messages=messages
)

answer = response.choices[0].message.content

 
display(Markdown(answer))
competitor.append(model_name)
# Out:
# Creating a sound and effective legal strategy to tackle the changing regulations in international law amid global shifts due to climate change, digitalization and geopolitical conflicts, requires a systematic approach. This strategy should cover monitoring regulatory changes, assessing impacts, updating legal compliance frameworks, and engaging in policy advocacy.
#
# 1. Regulatory Monitoring: Establish a dedicated team to keep track of international laws and potential changes that can significantly impact your affairs. This team can use legal databases, news alerts, and policy updates from reliable authorities to continue monitoring existing and proposed regulations.
#
# 2. Establish Partnerships: Partnering with law firms and consultancies in diverse jurisdictions will ensure you're aware of changes on the ground. This also includes partnerships with international law organizations.
#
# ...
